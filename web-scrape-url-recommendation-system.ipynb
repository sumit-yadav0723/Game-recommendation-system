# %%
import pandas as pd
import numpy as np
game_large = pd.read_csv('all_games.csv')
game_des = pd.read_csv('games_of_all_time.csv')

# %%
import requests
from bs4 import BeautifulSoup
headers={'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.131 Safari/537.36'}

# %%
l=[]
for i in game_des['url']:
    if(len(l)%500==0):
        print(len(l))
    web_page=requests.get(i,headers=headers).text
    soup=BeautifulSoup(web_page)
    l.append(str(soup.find('img',class_='product_image large_image')).split()[-1].split('"')[1])
    break
# Out:
# 0
# CPU times: user 240 ms, sys: 6.79 ms, total: 247 ms
# Wall time: 302 ms

# %%
img_url=[]

# %%
l=[]
for i in game_des['url']:
    if(len(l)%1000==0):
        print(len(l))
    try:
        web_page=requests.get(i,headers=headers).text
        soup=BeautifulSoup(web_page)
        l.append(str(soup.find('img',class_='product_image large_image')).split()[-1].split('"')[1])
    except:
        l.append(np.nan)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# CPU times: user 2min 28s, sys: 1.34 s, total: 2min 30s
# Wall time: 13min 27s

# %%
img_url.extend(l)

# %%
len(img_url)
# Out:
# 7728

# %%
img_url_df=pd.DataFrame(img_url)
img_url_df
# Out:
#                                                       0
# 0     https://static.metacritic.com/images/products/...
# 1     https://static.metacritic.com/images/products/...
# 2     https://static.metacritic.com/images/products/...
# 3     https://static.metacritic.com/images/products/...
# 4     https://static.metacritic.com/images/products/...
# ...                                                 ...
# 7723  https://static.metacritic.com/images/products/...
# 7724  https://static.metacritic.com/images/products/...
# 7725  https://static.metacritic.com/images/products/...
# 7726  https://static.metacritic.com/images/products/...
# 7727  https://static.metacritic.com/images/products/...
#
# [7728 rows x 1 columns]

# %%
img_url_df.to_csv("img_url.csv",index=False)
